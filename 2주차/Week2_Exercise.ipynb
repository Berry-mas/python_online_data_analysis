# %%
import requests

# %%
url = 'https://www.yes24.com/Product/Goods/96971128'

# %%
r = requests.get(url)

# %%
print(r.text)
# Out:
# 	<!DOCTYPE html >
# 	<html lang="ko">
#
# <head><link rel="canonical" href="https://m.yes24.com/Goods/Detail/96971128">
# 	<meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# 	<meta http-equiv="Content-Type" content="text/html;charset=utf-8" />
# 	<meta http-equiv="Accept-CH" content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version" />
# 	<meta http-equiv="Accept-CH-Lifetime" content="86400" />
# 	<meta name="referrer" content="unsafe-url" />
# 	<meta name="viewport" content="width=1170" />
#
# 	<title>어떤 죽음이 삶에게 말했다 - 예스24 </title>
#
#
# <meta name="title" content="어떤 죽음이 삶에게 말했다"/>
# <meta name="author" content="김범석 저" />
#
# <meta name="description" content="생의 남은 시간이 우리에게 들려주는 것. 김범석 저. 흐름출판. 구매혜택:[단독] 도도새 북마크 2종 증정(포인트 차감). 판매가 13,500원(10% 할인). 포인트 750원(5% 적립). 서울대병원 종양내과 의사가 기록한 마지막 흔적우리의 선택이 보여주는 ..."/>
#
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup (r.text, 'lxml')

# %%
soup.title.text
# Out:
# '어떤 죽음이 삶에게 말했다 - 예스24 '

# %%
soup.find('a', attrs={'herf':'김범석'})
