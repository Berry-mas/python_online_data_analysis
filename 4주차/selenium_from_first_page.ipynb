# %%
import time

from selenium import webdriver # selenium의 webdriver 모듈을 임포트 합니다.
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By

# chromedriver.exe 파일의 경로를 입력합니다.
s = Service(r'C:\Users\user\chromedriver-win64\chromedriver.exe')
driver = webdriver.Chrome(service=s)

url = 'http://www.yes24.com'
driver.get(url) 
time.sleep(2)
# '베스트' 링크 찾아서 클릭하기
element = driver.find_element(by=By.XPATH, value='//*[@id="yesFixCorner"]/dl/dd/ul[1]/li[1]/a')
element.click()

time.sleep(2)
# 베스트셀러 페이지의 첫 번째 책 링크 찾고 클릭하기
element = driver.find_element(by=By.XPATH, value='//*[@id="bestList"]/ol/li[1]/p[1]/a')
element.click()

html = driver.page_source # 해당 페이지의 source code 실시간으로 다운로드 받기
time.sleep(1)

driver.close()

# %%
# 셀레니엄을 이용해 다운로드된 소스코드 확인하기
print(html)
# Out:
# <html lang="ko"><head><link rel="canonical" href="https://www.yes24.com/Product/Goods/122090075"> <link rel="alternate" media="only screen and(max-width: 640px)" href="https://m.yes24.com/Goods/Detail/122090075">
# 	<meta http-equiv="X-UA-Compatible" content="IE=Edge">
# 	<meta http-equiv="Content-Type" content="text/html;charset=utf-8">
# 	<meta http-equiv="Accept-CH" content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version">
# 	<meta http-equiv="Accept-CH-Lifetime" content="86400">
# 	<meta name="referrer" content="unsafe-url">
# 	<meta name="viewport" content="width=1170">
#
# 	<title>도시와 그 불확실한 벽 - 예스24 </title>
#
#
# <meta name="title" content="도시와 그 불확실한 벽">
# <meta name="author" content="무라카미 하루키 저/홍은주 역">
#
# <meta name="description" content="무라카미 하루키 저/홍은주 역. 문학동네. 구매혜택:작가 포스터/포함 국내도서 3만원 ↑ 하루키 블랙 머그 증정(개별 포인트 차감). 판매가 17,550원(10% 할인). 포인트 970원(5% 적립). 첫 발표 이후 43년, 마음에 품어왔던 소설을 마침내 완성...">
#
# ...

# %% [markdown]
# BeautifulSoup을 이용해서 태그를 찾고, 태그로부터 정보 추출하기

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html, 'lxml')

# %%
sub_tags = soup.find('span', attrs={'class':"gd_best gd_best_tp02"})

# %%
sub_tags
# Out:
# <span class="gd_best gd_best_tp02">
# <dl>
# <dt>베스트</dt>
# <dd>
# <a href="javascript:void(0)" onclick="openUrl('/24/category/bestseller?CategoryNumber=001&amp;SumGb=02','Pcode','003_008')">국내도서 1위</a>
# <em class="divi">|</em>
#             국내도서 1위 2주
#         </dd>
# </dl>
# </span>
