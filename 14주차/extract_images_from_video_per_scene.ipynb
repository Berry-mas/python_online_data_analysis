# %%
import cv2
from scenedetect import VideoManager
from scenedetect import SceneManager
from scenedetect.detectors import ContentDetector

# %%
# 씬 찾기
def find_scenes(video_path, threshold=27.0):
    # 비디오 매니저와 장면 매니저를 생성합니다.
    video_manager = VideoManager([video_path])
    scene_manager = SceneManager()
    
    # 장면 감지기를 추가합니다 (여기서는 내용 기반 감지기를 사용합니다).
    scene_manager.add_detector(ContentDetector(threshold=threshold))
    # ContentDectector => 인접한 프레임 간 색 변화 정도를 파악하여 씬 탐지 
    # 색 변화 정도가 threshold 값보다 크면 다른 씬으로 간주
    # Threshold 값은 일반적으로 27 정도 사용 
    
    # 비디오 매니저를 초기화합니다.
    video_manager.set_downscale_factor()
    video_manager.start()

    # 장면을 감지합니다.
    scene_manager.detect_scenes(frame_source=video_manager)

    # 감지된 장면의 시작 시간을 반환합니다.
    return scene_manager.get_scene_list()

# %%
# 각 씬의 첫 번째 프레임 저장
def save_images(video_path, scenes, output_folder):
    # 비디오 파일을 엽니다.
    cap = cv2.VideoCapture(video_path)
    for i, scene in enumerate(scenes):
        # 각 장면의 첫 번째 프레임으로 이동합니다.
        frame_num = scene[0].get_frames()
        cap.set(cv2.CAP_PROP_POS_FRAMES, frame_num)
        
        # 프레임을 읽습니다.
        ret, frame = cap.read()
        if ret:
            # 이미지 파일로 저장합니다.
            cv2.imwrite(f'{output_folder}/scene_{i+1}.jpg', frame)
            print(f'Scene {i+1} saved: {output_folder}/scene_{i+1}.jpg')
            
    # 비디오 캡처를 해제합니다.
    cap.release()

# %%
video_path = './taxi_driver.mp4/'
output_folder = './Images_per_scene/'
scenes = find_scenes(video_path, threshold=27.0)  # 장면 감지 임계값 설정
# Out:
# VideoManager is deprecated and will be removed.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[16], line 3
#       1 video_path = './taxi_driver.mp4/'
#       2 output_folder = './Images_per_scene/'
# ----> 3 scenes = find_scenes(video_path, threshold=27.0)
#
# Cell In[9], line 4, in find_scenes(video_path, threshold)
#       2 def find_scenes(video_path, threshold=27.0):
#       3     # 비디오 매니저와 장면 매니저를 생성합니다.
# ----> 4     video_manager = VideoManager([video_path])
#       5     scene_manager = SceneManager()
#       7     # 장면 감지기를 추가합니다 (여기서는 내용 기반 감지기를 사용합니다).
#
# File ~\anaconda3\Lib\site-packages\scenedetect\video_manager.py:323, in VideoManager.__init__(self, video_files, framerate, logger)
#     321 # These VideoCaptures are only open in this process.
#     322 self._is_device = isinstance(video_files[0], int)
# --> 323 self._cap_list, self._cap_framerate, self._cap_framesize = open_captures(
#     324     video_files=video_files, framerate=framerate
#     325 )
#     326 self._path = video_files[0] if not self._is_device else video_files
#     327 self._end_of_video = False
#
# File ~\anaconda3\Lib\site-packages\scenedetect\video_manager.py:148, in open_captures(video_files, framerate, validate_parameters)
#     139 # Check if files exist if passed video file is not an image sequence
#     140 # (checked with presence of % in filename) or not a URL (://).
#     141 if not is_device and any(
#     142     [
#     143         not os.path.exists(video_file)
#    (...)
#     146     ]
#     147 ):
# --> 148     raise OSError("Video file(s) not found.")
#     149 cap_list = []
#     151 try:
#
# OSError: Video file(s) not found.

# %%
scenes
# (00:00:00.000 [frame=0, fps=23.976], 00:00:03.003 [frame=72, fps=23.976])
# 씬의 시작 시간과 끝 시간
# Out:
# [(00:00:00.000 [frame=0, fps=23.976], 00:00:03.003 [frame=72, fps=23.976]),
#  (00:00:03.003 [frame=72, fps=23.976], 00:00:03.837 [frame=92, fps=23.976]),
#  (00:00:03.837 [frame=92, fps=23.976], 00:00:04.713 [frame=113, fps=23.976]),
#  (00:00:04.713 [frame=113, fps=23.976], 00:00:05.839 [frame=140, fps=23.976]),
#  (00:00:05.839 [frame=140, fps=23.976], 00:00:06.965 [frame=167, fps=23.976]),
#  (00:00:06.965 [frame=167, fps=23.976], 00:00:08.175 [frame=196, fps=23.976]),
#  (00:00:08.175 [frame=196, fps=23.976], 00:00:09.134 [frame=219, fps=23.976]),
#  (00:00:09.134 [frame=219, fps=23.976], 00:00:10.093 [frame=242, fps=23.976]),
#  (00:00:10.093 [frame=242, fps=23.976], 00:00:11.220 [frame=269, fps=23.976]),
#  (00:00:11.220 [frame=269, fps=23.976], 00:00:11.929 [frame=286, fps=23.976]),
#  (00:00:11.929 [frame=286, fps=23.976], 00:00:13.055 [frame=313, fps=23.976]),
#  (00:00:13.055 [frame=313, fps=23.976], 00:00:13.931 [frame=334, fps=23.976]),
#  (00:00:13.931 [frame=334, fps=23.976], 00:00:15.349 [frame=368, fps=23.976]),
#  (00:00:15.349 [frame=368, fps=23.976], 00:00:16.558 [frame=397, fps=23.976]),
#  (00:00:16.558 [frame=397, fps=23.976], 00:00:18.352 [frame=440, fps=23.976]),
#  (00:00:18.352 [frame=440, fps=23.976], 00:00:19.853 [frame=476, fps=23.976]),
#  (00:00:19.853 [frame=476, fps=23.976], 00:00:21.230 [frame=509, fps=23.976]),
#  (00:00:21.230 [frame=509, fps=23.976], 00:00:22.397 [frame=537, fps=23.976]),
#  (00:00:22.397 [frame=537, fps=23.976], 00:00:23.232 [frame=557, fps=23.976]),
#  (00:00:23.232 [frame=557, fps=23.976], 00:00:24.149 [frame=579, fps=23.976]),
#  (00:00:24.149 [frame=579, fps=23.976], 00:00:25.901 [frame=621, fps=23.976]),
#  (00:00:25.901 [frame=621, fps=23.976], 00:00:27.027 [frame=648, fps=23.976]),
#  (00:00:27.027 [frame=648, fps=23.976], 00:00:27.903 [frame=669, fps=23.976]),
#  (00:00:27.903 [frame=669, fps=23.976], 00:00:29.363 [frame=704, fps=23.976]),
#  (00:00:29.363 [frame=704, fps=23.976], 00:00:30.530 [frame=732, fps=23.976]),
#  (00:00:30.530 [frame=732, fps=23.976], 00:00:31.406 [frame=753, fps=23.976]),
#  (00:00:31.406 [frame=753, fps=23.976], 00:00:32.324 [frame=775, fps=23.976]),
#  (00:00:32.324 [frame=775, fps=23.976], 00:00:33.659 [frame=807, fps=23.976]),
#  (00:00:33.659 [frame=807, fps=23.976], 00:00:35.535 [frame=852, fps=23.976]),
#  (00:00:35.535 [frame=852, fps=23.976], 00:00:36.912 [frame=885, fps=23.976]),
#  (00:00:36.912 [frame=885, fps=23.976], 00:00:37.704 [frame=904, fps=23.976]),
#  (00:00:37.704 [frame=904, fps=23.976], 00:00:38.538 [frame=924, fps=23.976]),
#  (00:00:38.538 [frame=924, fps=23.976], 00:00:39.748 [frame=953, fps=23.976]),
#  (00:00:39.748 [frame=953, fps=23.976], 00:00:40.666 [frame=975, fps=23.976]),
#  (00:00:40.666 [frame=975, fps=23.976], 00:00:41.917 [frame=1005, fps=23.976]),
#  (00:00:41.917 [frame=1005, fps=23.976],
#   00:00:42.793 [frame=1026, fps=23.976]),
#  (00:00:42.793 [frame=1026, fps=23.976],
#   00:00:43.585 [frame=1045, fps=23.976]),
#  (00:00:43.585 [frame=1045, fps=23.976],
#   00:00:44.419 [frame=1065, fps=23.976]),
#  (00:00:44.419 [frame=1065, fps=23.976],
#   00:00:45.295 [frame=1086, fps=23.976]),
#  (00:00:45.295 [frame=1086, fps=23.976],
#   00:00:46.463 [frame=1114, fps=23.976]),
#  (00:00:46.463 [frame=1114, fps=23.976],
#   00:00:47.589 [frame=1141, fps=23.976]),
#  (00:00:47.589 [frame=1141, fps=23.976],
#   00:00:48.340 [frame=1159, fps=23.976]),
#  (00:00:48.340 [frame=1159, fps=23.976],
#   00:00:49.132 [frame=1178, fps=23.976]),
#  (00:00:49.132 [frame=1178, fps=23.976],
#   00:00:49.841 [frame=1195, fps=23.976]),
#  (00:00:49.841 [frame=1195, fps=23.976],
#   00:00:50.592 [frame=1213, fps=23.976]),
#  (00:00:50.592 [frame=1213, fps=23.976],
#   00:00:52.052 [frame=1248, fps=23.976]),
#  (00:00:52.052 [frame=1248, fps=23.976],
#   00:00:53.387 [frame=1280, fps=23.976]),
#  (00:00:53.387 [frame=1280, fps=23.976],
#   00:00:55.639 [frame=1334, fps=23.976]),
#  (00:00:55.639 [frame=1334, fps=23.976],
#   00:01:00.519 [frame=1451, fps=23.976]),
#  (00:01:00.519 [frame=1451, fps=23.976],
#   00:01:02.854 [frame=1507, fps=23.976]),
#  (00:01:02.854 [frame=1507, fps=23.976],
#   00:01:04.231 [frame=1540, fps=23.976]),
#  (00:01:04.231 [frame=1540, fps=23.976],
#   00:01:06.024 [frame=1583, fps=23.976]),
#  (00:01:06.024 [frame=1583, fps=23.976],
#   00:01:07.109 [frame=1609, fps=23.976]),
#  (00:01:07.109 [frame=1609, fps=23.976],
#   00:01:08.735 [frame=1648, fps=23.976]),
#  (00:01:08.735 [frame=1648, fps=23.976],
#   00:01:09.653 [frame=1670, fps=23.976]),
#  (00:01:09.653 [frame=1670, fps=23.976],
#   00:01:10.279 [frame=1685, fps=23.976]),
#  (00:01:10.279 [frame=1685, fps=23.976],
#   00:01:12.030 [frame=1727, fps=23.976]),
#  (00:01:12.030 [frame=1727, fps=23.976],
#   00:01:12.948 [frame=1749, fps=23.976]),
#  (00:01:12.948 [frame=1749, fps=23.976],
#   00:01:13.740 [frame=1768, fps=23.976]),
#  (00:01:13.740 [frame=1768, fps=23.976],
#   00:01:14.408 [frame=1784, fps=23.976]),
#  (00:01:14.408 [frame=1784, fps=23.976],
#   00:01:15.909 [frame=1820, fps=23.976]),
#  (00:01:15.909 [frame=1820, fps=23.976],
#   00:01:21.039 [frame=1943, fps=23.976]),
#  (00:01:21.039 [frame=1943, fps=23.976],
#   00:01:22.666 [frame=1982, fps=23.976]),
#  (00:01:22.666 [frame=1982, fps=23.976],
#   00:01:24.960 [frame=2037, fps=23.976]),
#  (00:01:24.960 [frame=2037, fps=23.976],
#   00:01:27.087 [frame=2088, fps=23.976]),
#  (00:01:27.087 [frame=2088, fps=23.976],
#   00:01:28.255 [frame=2116, fps=23.976]),
#  (00:01:28.255 [frame=2116, fps=23.976],
#   00:01:29.172 [frame=2138, fps=23.976]),
#  (00:01:29.172 [frame=2138, fps=23.976],
#   00:01:30.632 [frame=2173, fps=23.976]),
#  (00:01:30.632 [frame=2173, fps=23.976],
#   00:01:31.550 [frame=2195, fps=23.976]),
#  (00:01:31.550 [frame=2195, fps=23.976],
#   00:01:32.426 [frame=2216, fps=23.976]),
#  (00:01:32.426 [frame=2216, fps=23.976],
#   00:01:33.427 [frame=2240, fps=23.976]),
#  (00:01:33.427 [frame=2240, fps=23.976],
#   00:01:35.470 [frame=2289, fps=23.976]),
#  (00:01:35.470 [frame=2289, fps=23.976],
#   00:01:37.889 [frame=2347, fps=23.976]),
#  (00:01:37.889 [frame=2347, fps=23.976],
#   00:01:45.689 [frame=2534, fps=23.976]),
#  (00:01:45.689 [frame=2534, fps=23.976],
#   00:01:48.317 [frame=2597, fps=23.976]),
#  (00:01:48.317 [frame=2597, fps=23.976],
#   00:01:50.027 [frame=2638, fps=23.976])]

# %%
# 각 씬의 첫 번째 프레임 저장
save_images(video_path, scenes, output_folder)
# Out:
# Scene 1 saved: ./Images_per_scene//scene_1.jpg
# Scene 2 saved: ./Images_per_scene//scene_2.jpg
# Scene 3 saved: ./Images_per_scene//scene_3.jpg
# Scene 4 saved: ./Images_per_scene//scene_4.jpg
# Scene 5 saved: ./Images_per_scene//scene_5.jpg
# Scene 6 saved: ./Images_per_scene//scene_6.jpg
# Scene 7 saved: ./Images_per_scene//scene_7.jpg
# Scene 8 saved: ./Images_per_scene//scene_8.jpg
# Scene 9 saved: ./Images_per_scene//scene_9.jpg
# Scene 10 saved: ./Images_per_scene//scene_10.jpg
# Scene 11 saved: ./Images_per_scene//scene_11.jpg
# Scene 12 saved: ./Images_per_scene//scene_12.jpg
# Scene 13 saved: ./Images_per_scene//scene_13.jpg
# Scene 14 saved: ./Images_per_scene//scene_14.jpg
# Scene 15 saved: ./Images_per_scene//scene_15.jpg
# Scene 16 saved: ./Images_per_scene//scene_16.jpg
# Scene 17 saved: ./Images_per_scene//scene_17.jpg
# Scene 18 saved: ./Images_per_scene//scene_18.jpg
# Scene 19 saved: ./Images_per_scene//scene_19.jpg
# Scene 20 saved: ./Images_per_scene//scene_20.jpg
# Scene 21 saved: ./Images_per_scene//scene_21.jpg
# Scene 22 saved: ./Images_per_scene//scene_22.jpg
# Scene 23 saved: ./Images_per_scene//scene_23.jpg
# Scene 24 saved: ./Images_per_scene//scene_24.jpg
# Scene 25 saved: ./Images_per_scene//scene_25.jpg
# Scene 26 saved: ./Images_per_scene//scene_26.jpg
# Scene 27 saved: ./Images_per_scene//scene_27.jpg
# Scene 28 saved: ./Images_per_scene//scene_28.jpg
# Scene 29 saved: ./Images_per_scene//scene_29.jpg
# Scene 30 saved: ./Images_per_scene//scene_30.jpg
# Scene 31 saved: ./Images_per_scene//scene_31.jpg
# Scene 32 saved: ./Images_per_scene//scene_32.jpg
# Scene 33 saved: ./Images_per_scene//scene_33.jpg
# Scene 34 saved: ./Images_per_scene//scene_34.jpg
# Scene 35 saved: ./Images_per_scene//scene_35.jpg
# Scene 36 saved: ./Images_per_scene//scene_36.jpg
# Scene 37 saved: ./Images_per_scene//scene_37.jpg
# Scene 38 saved: ./Images_per_scene//scene_38.jpg
# Scene 39 saved: ./Images_per_scene//scene_39.jpg
# Scene 40 saved: ./Images_per_scene//scene_40.jpg
# Scene 41 saved: ./Images_per_scene//scene_41.jpg
# Scene 42 saved: ./Images_per_scene//scene_42.jpg
# Scene 43 saved: ./Images_per_scene//scene_43.jpg
# Scene 44 saved: ./Images_per_scene//scene_44.jpg
# Scene 45 saved: ./Images_per_scene//scene_45.jpg
# Scene 46 saved: ./Images_per_scene//scene_46.jpg
# Scene 47 saved: ./Images_per_scene//scene_47.jpg
# Scene 48 saved: ./Images_per_scene//scene_48.jpg
# Scene 49 saved: ./Images_per_scene//scene_49.jpg
# Scene 50 saved: ./Images_per_scene//scene_50.jpg
# Scene 51 saved: ./Images_per_scene//scene_51.jpg
# Scene 52 saved: ./Images_per_scene//scene_52.jpg
# Scene 53 saved: ./Images_per_scene//scene_53.jpg
# Scene 54 saved: ./Images_per_scene//scene_54.jpg
# Scene 55 saved: ./Images_per_scene//scene_55.jpg
# Scene 56 saved: ./Images_per_scene//scene_56.jpg
# Scene 57 saved: ./Images_per_scene//scene_57.jpg
# Scene 58 saved: ./Images_per_scene//scene_58.jpg
# Scene 59 saved: ./Images_per_scene//scene_59.jpg
# Scene 60 saved: ./Images_per_scene//scene_60.jpg
# Scene 61 saved: ./Images_per_scene//scene_61.jpg
# Scene 62 saved: ./Images_per_scene//scene_62.jpg
# Scene 63 saved: ./Images_per_scene//scene_63.jpg
# Scene 64 saved: ./Images_per_scene//scene_64.jpg
# Scene 65 saved: ./Images_per_scene//scene_65.jpg
# Scene 66 saved: ./Images_per_scene//scene_66.jpg
# Scene 67 saved: ./Images_per_scene//scene_67.jpg
# Scene 68 saved: ./Images_per_scene//scene_68.jpg
# Scene 69 saved: ./Images_per_scene//scene_69.jpg
# Scene 70 saved: ./Images_per_scene//scene_70.jpg
# Scene 71 saved: ./Images_per_scene//scene_71.jpg
# Scene 72 saved: ./Images_per_scene//scene_72.jpg
# Scene 73 saved: ./Images_per_scene//scene_73.jpg
# Scene 74 saved: ./Images_per_scene//scene_74.jpg
# Scene 75 saved: ./Images_per_scene//scene_75.jpg
# Scene 76 saved: ./Images_per_scene//scene_76.jpg
